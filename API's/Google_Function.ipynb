# %%
import pandas as pd

# %%
datafile = "input_data/real_estate.csv"

# %%
df = pd.read_csv(datafile)
df.head()
# Out:
#      SALE TYPE  SOLD DATE              PROPERTY TYPE  \
# 0  MLS Listing        NaN                Condo/Co-op
# 1  MLS Listing        NaN                Condo/Co-op
# 2  MLS Listing        NaN                Condo/Co-op
# 3  MLS Listing        NaN                  Townhouse
# 4  MLS Listing        NaN  Single Family Residential
#
#                          ADDRESS        CITY STATE    ZIP   PRICE  BEDS  \
# 0  1391 Pennsylvania Ave SE #202  Washington    DC  20003  414900   1.0
# 1   5410 Connecticut Ave NW #308  Washington    DC  20015  269000   1.0
# 2               311 4th St SE #1  Washington    DC  20003  299900   1.0
# 3                   3538 W Pl NW  Washington    DC  20007  924900   4.0
# 4               5522 Blair Rd NE  Washington    DC  20011  499000   2.0
#
#    BATHS    ...      STATUS  NEXT OPEN HOUSE START TIME  \
# 0    1.0    ...      Active       June-24-2018 01:00 PM
# 1    1.0    ...      Active       June-24-2018 01:00 PM
# ...

# %%
coords = []

for index, row in df.iterrows():
    print(str(row['LATITUDE']) + ','+ (str(row['LONGITUDE'])))
    x = str(row['LATITUDE']) + ','+ (str(row['LONGITUDE']))
    coords.append(x)
# Out:
# 38.880206099999995,-76.98761230000001
# 38.961853376,-77.07387407
# 38.884949600000006,-77.0007114
# 38.918407,-77.071688
# 38.9573484,-77.0081579
# 38.9166276,-77.027795
# 38.8694972,-76.95496659999999
# 38.9894012,-77.03469770000001
# 38.9022284,-76.99812440000001
# 38.9106399,-77.03877059999999
# 38.958401200000004,-76.9957284
# 38.9153737,-77.04237679999999
# 38.928090000000005,-77.078147
# 38.9379082,-77.05865
# 38.905462299999996,-77.018336
# 38.9070003,-77.03067390000001
# 38.924488700000005,-77.03935899999999
# 38.934817100000004,-77.08284420000001
# 38.919439399999995,-77.01429909999999
# 38.9181344,-77.0732155
# 38.9265812,-77.0347898
# 38.9619842,-77.0740567
# 38.9370187,-77.0621578
# 38.92370510000001,-77.0792721
# 38.916374600000005,-77.0428053
# 38.923402,-77.031301
# 38.925669899999995,-77.034101
# 38.909879499999995,-77.0387347
# 38.878060999999995,-77.00439279999999
# 38.9070003,-77.03067390000001
# 38.89905,-77.052542
# 38.904343,-77.05232679999999
# ...

# %%
coords
# Out:
# 350

# %%
# Dependencies
import requests
import json

# Google developer API key
# from config import gkey

gkey = "AIzaSyDBvwVcdWCFV7gOuJth9-omy6VEo-BBo_E"

# %%
for x in coords:

    # geocoordinates
    target_coordinates = x
    target_search = "bar"
    target_radius = 100
    target_type = "restaurant"

    # set up a parameters dictionary
    params = {
        "location": target_coordinates,
        "keyword": target_search,
        "radius": target_radius,
        "type": target_type,
        "key": gkey
    }

    # base url
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # run a request using our params dictionary
    response = requests.get(base_url, params=params)
    
    # print the response url, avoid doing for public github repos in order to avoid exposing key
    print(response.url)
    print()
    
    # convert response to json
    places_data = response.json()
    
    for x in places_data["results"]:
        print(x["name"])
# Out:
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.880206099999995%2C-76.98761230000001&keyword=bar&radius=100&type=restaurant&key=AIzaSyDBvwVcdWCFV7gOuJth9-omy6VEo-BBo_E
#
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.961853376%2C-77.07387407&keyword=bar&radius=100&type=restaurant&key=AIzaSyDBvwVcdWCFV7gOuJth9-omy6VEo-BBo_E
#
# Blue 44 Restaurant and Bar
# Parthenon Restaurant & Chevy Chase Lounge
# Macon Bistro & Larder
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.884949600000006%2C-77.0007114&keyword=bar&radius=100&type=restaurant&key=AIzaSyDBvwVcdWCFV7gOuJth9-omy6VEo-BBo_E
#
# Sonoma Restaurant and Wine Bar
# Hank's Oyster Bar
# Beuchert’s Saloon
# Mr. Henry's Restaurant
# Hawk 'n' Dove
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=38.918407%2C-77.071688&keyword=bar&radius=100&type=restaurant&key=AIzaSyDBvwVcdWCFV7gOuJth9-omy6VEo-BBo_E
#
# ...
